# %% [markdown]
# # 주식 데이터 불러오기

# %% [markdown]
# ## 요건 정리
#
# - 원하는 종목을 지정해야함
# - 종목의 종가를 불러 올 수 있어야함
# - 종가를 원하는 기간에 걸쳐서 불러와야함
# - 종목 끼리의 값 비교를 할 수 있어야 함
# - 종목 끼리의 공분산 / 상관계수를 구할 수 있어야 함

# %%
import FinanceDataReader as fdr

# %%
# 국내시장 종목정보 불러오기

df_krx = fdr.StockListing('KRX')
df_krx.head()
# Out:
#      Code        ISU_CD      Name Market Dept   Close ChangeCode  Changes  \
# 0  005930  KR7005930003      삼성전자  KOSPI        62400          1      500
# 1  373220  KR7373220003  LG에너지솔루션  KOSPI       596000          2    -8000
# 2  000660  KR7000660001    SK하이닉스  KOSPI        91600          1      700
# 3  207940  KR7207940008  삼성바이오로직스  KOSPI       906000          1     5000
# 4  051910  KR7051910008      LG화학  KOSPI       710000          2   -16000
#
#    ChagesRatio    Open    High     Low    Volume        Amount  \
# 0         0.81   62200   62500   61600  12310986  764117239743
# 1        -1.32  604000  610000  586000    380071  226266348838
# 2         0.77   91300   92100   90400   2460465  224722829263
# 3         0.55  909000  910000  901000     39296   35603962000
# 4        -2.20  735000  740000  703000    317416  226915479000
#
#             Marcap      Stocks MarketId
# 0  372514431120000  5969782550      STK
# 1  139464000000000   234000000      STK
# 2   66685016634000   728002365      STK
# 3   64483644000000    71174000      STK
# 4   50120563530000    70592343      STK

# %%
df_krx.shape
# Out:
# (2671, 17)

# %%
code_name_dict = dict() # 주식 종목코드와 종목명이 담길 dict 선언
name_code_dict = dict() # name : code 형식으로 하나 더

# %%
for i in range(df_krx.shape[0]):
    code_name_dict[df_krx['Code'][i]]=df_krx['Name'][i]
    name_code_dict[df_krx['Name'][i]]=df_krx['Code'][i]
    
code_name_dict
name_code_dict
# Out:
# {'삼성전자': '005930',
#  'LG에너지솔루션': '373220',
#  'SK하이닉스': '000660',
#  '삼성바이오로직스': '207940',
#  'LG화학': '051910',
#  '삼성SDI': '006400',
#  '삼성전자우': '005935',
#  '현대차': '005380',
#  'NAVER': '035420',
#  '기아': '000270',
#  '셀트리온': '068270',
#  '카카오': '035720',
#  'POSCO홀딩스': '005490',
#  '삼성물산': '028260',
#  '현대모비스': '012330',
#  'KB금융': '105560',
#  '신한지주': '055550',
#  '포스코케미칼': '003670',
#  'SK이노베이션': '096770',
#  'SK': '034730',
#  'LG전자': '066570',
#  '카카오뱅크': '323410',
#  'LG': '003550',
#  '삼성생명': '032830',
#  'KT&G': '033780',
#  '고려아연': '010130',
#  '한국전력': '015760',
#  '하나금융지주': '086790',
#  '에코프로비엠': '247540',
#  'SK텔레콤': '017670',
#  '셀트리온헬스케어': '091990',
#  '두산에너빌리티': '034020',
#  '크래프톤': '259960',
#  '삼성전기': '009150',
#  'HMM': '011200',
#  'LG생활건강': '051900',
#  '현대중공업': '329180',
#  '엔씨소프트': '036570',
#  '삼성에스디에스': '018260',
#  'S-Oil': '010950',
#  '대한항공': '003490',
#  'KT': '030200',
#  '한화솔루션': '009830',
#  '삼성화재': '000810',
#  '우리금융지주': '316140',
#  '카카오페이': '377300',
#  '엘앤에프': '066970',
#  '기업은행': '024110',
#  'LG이노텍': '011070',
#  'SK바이오사이언스': '302440',
#  '아모레퍼시픽': '090430',
#  '현대글로비스': '086280',
#  '롯데케미칼': '011170',
#  'F&F': '383220',
#  'CJ제일제당': '097950',
#  'SK바이오팜': '326030',
#  '하이브': '352820',
#  'SK스퀘어': '402340',
#  '한국조선해양': '009540',
#  'LG디스플레이': '034220',
#  'LG유플러스': '032640',
#  '강원랜드': '035250',
#  '삼성엔지니어링': '028050',
#  'HD현대': '267250',
#  '삼성중공업': '010140',
#  '한온시스템': '018880',
#  '현대건설': '000720',
#  '맥쿼리인프라': '088980',
#  'SK아이이테크놀로지': '361610',
#  '금호석유': '011780',
#  '넷마블': '251270',
#  '현대제철': '004020',
#  '한국항공우주': '047810',
#  'GS': '078930',
#  'SKC': '011790',
#  '유한양행': '000100',
#  '코웨이': '021240',
#  '한국타이어앤테크놀로지': '161390',
#  '오리온': '271560',
#  '미래에셋증권': '006800',
#  'HLB': '028300',
#  'DB손해보험': '005830',
#  '메리츠화재': '000060',
#  '메리츠금융지주': '138040',
#  '두산밥캣': '241560',
#  '카카오게임즈': '293490',
#  '삼성카드': '029780',
#  '에스디바이오센서': '137310',
#  '현대미포조선': '010620',
#  '한화에어로스페이스': '012450',
#  '롯데지주': '004990',
#  '에코프로': '086520',
#  '한미약품': '128940',
#  'BGF리테일': '282330',
#  '현대오토에버': '307950',
#  '한국가스공사': '036460',
#  '한국금융지주': '071050',
#  'NH투자증권': '005940',
#  '삼성증권': '016360',
#  '현대차2우B': '005387',
#  '쌍용C&E': '003410',
#  '일진머티리얼즈': '020150',
#  '씨에스윈드': '112610',
#  '메리츠증권': '008560',
#  'GS리테일': '007070',
#  '팬오션': '028670',
#  '호텔신라': '008770',
#  '펄어비스': '263750',
#  '포스코인터내셔널': '047050',
#  '현대로템': '064350',
#  '한진칼': '180640',
#  '셀트리온제약': '068760',
#  '제일기획': '030000',
#  '이마트': '139480',
#  '천보': '278280',
#  '아모레G': '002790',
#  '롯데쇼핑': '023530',
#  '현대해상': '001450',
#  'LG화학우': '051915',
#  'OCI': '010060',
#  '에스원': '012750',
#  '한전기술': '052690',
#  '키움증권': '039490',
#  '한미사이언스': '008930',
#  'HL만도': '204320',
#  '한솔케미칼': '014680',
#  '두산퓨얼셀': '336260',
#  '리노공업': '058470',
#  '대한전선': '001440',
#  'CJ': '001040',
#  '한화시스템': '272210',
#  'KCC': '002380',
#  'BNK금융지주': '138930',
#  '동서': '026960',
#  'LS': '006260',
#  'DB하이텍': '000990',
#  '알테오젠': '196170',
#  '영원무역': '111770',
#  '신세계': '004170',
#  '한화': '000880',
#  'CJ대한통운': '000120',
#  'GS건설': '006360',
#  '대우조선해양': '042660',
#  'JYP Ent.': '035900',
#  '휠라홀딩스': '081660',
#  '현대차우': '005385',
#  '대우건설': '047040',
#  '한화생명': '088350',
#  '스튜디오드래곤': '253450',
#  'LIG넥스원': '079550',
#  '코스모신소재': '005070',
#  '농심': '004370',
#  '위메이드': '112040',
#  '하이트진로': '000080',
#  'CJ ENM': '035760',
#  'SK케미칼': '285130',
#  '씨젠': '096530',
#  '더블유씨피': '393890',
#  '대웅제약': '069620',
#  '동진쎄미켐': '005290',
#  '오뚜기': '007310',
#  '서울가스': '017390',
#  '효성첨단소재': '298050',
#  '금양': '001570',
#  '대성홀딩스': '016710',
#  '현대위아': '011210',
#  '솔브레인': '357780',
#  '녹십자': '006280',
#  '오스템임플란트': '048260',
#  '롯데정밀화학': '004000',
#  '에스엠': '041510',
#  '신풍제약': '019170',
#  'LS ELECTRIC': '010120',
#  '효성티앤씨': '298020',
#  '한전KPS': '051600',
#  '효성': '004800',
#  '에스티팜': '237690',
#  'LX세미콘': '108320',
#  '파라다이스': '034230',
#  '두산': '000150',
#  'DL이앤씨': '375500',
#  'LX인터내셔널': '001120',
#  '성일하이텍': '365340',
#  '현대두산인프라코어': '042670',
#  '영풍': '000670',
#  'JB금융지주': '175330',
#  '현대일렉트릭': '267260',
#  '원익IPS': '240810',
#  '대주전자재료': '078600',
#  '쌍용차': '003620',
#  '네이처셀': '007390',
#  '휴젤': '145020',
#  '동화기업': '025900',
#  '동원시스템즈': '014820',
#  '솔루스첨단소재': '336370',
#  'DL': '000210',
#  '에스에프에이': '056190',
#  '현대백화점': '069960',
#  '에스엘': '005850',
#  'HPSP': '403870',
#  '롯데칠성': '005300',
#  '코오롱인더': '120110',
#  '후성': '093370',
#  '일진하이솔루스': '271940',
#  '한미반도체': '042700',
#  '삼천리': '004690',
#  '대덕전자': '353200',
#  '티씨케이': '064760',
#  '대웅': '003090',
#  '클래시스': '214150',
#  '동국제강': '001230',
#  '한국앤컴퍼니': '000240',
#  '삼강엠앤티': '100090',
#  'DGB금융지주': '139130',
#  'HLB생명과학': '067630',
#  '케어젠': '214370',
#  '현대엘리베이': '017800',
#  '한샘': '009240',
#  '롯데제과': '280360',
#  '심텍': '222800',
#  '에이비엘바이오': '298380',
#  '롯데렌탈': '089860',
#  'SK가스': '018670',
#  'HK이노엔': '195940',
#  '대한유화': '006650',
#  '엔켐': '348370',
#  '아프리카TV': '067160',
#  '현대바이오': '048410',
#  '일동제약': '249420',
#  '케이엠더블유': '032500',
#  '더존비즈온': '012510',
#  '아이에스동서': '010780',
#  '종근당': '185750',
#  '피엔티': '137400',
#  'SK네트웍스': '001740',
#  'GKL': '114090',
#  '넥슨게임즈': '225570',
#  '덕산네오룩스': '213420',
#  '나노신소재': '121600',
#  'PI첨단소재': '178920',
#  '포스코 ICT': '022100',
#  '현대건설기계': '267270',
#  '신라젠': '215600',
#  '솔루엠': '248070',
#  '명신산업': '009900',
#  '고영': '098460',
#  '금호타이어': '073240',
#  '코리안리': '003690',
#  '레고켐바이오': '141080',
#  '아시아나항공': '020560',
#  'KG스틸': '016380',
#  '다우기술': '023590',
#  '오리온홀딩스': '001800',
#  '롯데리츠': '330590',
#  'SK리츠': '395400',
#  '한국콜마': '161890',
#  '에코프로에이치엔': '383310',
#  '메가스터디교육': '215200',
#  '비에이치': '090460',
#  '신세계인터내셔날': '031430',
#  '동원산업': '006040',
#  'TKG휴켐스': '069260',
#  'NHN': '181710',
#  '덴티움': '145720',
#  '이오테크닉스': '039030',
#  '카나리아바이오': '016790',
#  '한일시멘트': '300720',
#  '바이오니아': '064550',
#  '더블유게임즈': '192080',
#  '하림지주': '003380',
#  '녹십자홀딩스': '005250',
#  '동양생명': '082640',
#  '하나투어': '039130',
#  '미원상사': '002840',
#  '이노션': '214320',
#  '코스모화학': '005420',
#  '제이알글로벌리츠': '348950',
#  'F&F홀딩스': '007700',
#  '풍산': '103140',
#  '롯데관광개발': '032350',
#  '태광산업': '003240',
#  '메디톡스': '086900',
#  '네오위즈': '095660',
#  '차바이오텍': '085660',
#  '율촌화학': '008730',
#  '씨아이에스': '222080',
#  '컴투스': '078340',
#  '미원에스씨': '268280',
#  '다우데이타': '032190',
#  '이수화학': '005950',
#  'NICE평가정보': '030190',
#  'ESR켄달스퀘어리츠': '365550',
#  '지씨셀': '144510',
#  '코오롱티슈진': '950160',
#  '파크시스템스': '140860',
#  '한올바이오파마': '009420',
#  '삼천당제약': '000250',
#  'SFA반도체': '036540',
#  '미래나노텍': '095500',
#  '와이지엔터테인먼트': '122870',
#  'LG전자우': '066575',
#  '영원무역홀딩스': '009970',
#  '삼양식품': '003230',
#  '선광': '003100',
#  '위지윅스튜디오': '299900',
#  '동국제약': '086450',
#  '에스티큐브': '052020',
#  'HDC현대산업개발': '294870',
#  'CJ CGV': '079160',
#  '보령': '003850',
#  '진에어': '272450',
#  '해성디에스': '195870',
#  '대신증권': '003540',
#  '하나머티리얼즈': '166090',
#  '대상': '001680',
#  '원익QnC': '074600',
#  '콜마비앤에이치': '200130',
#  '대한해운': '005880',
#  'LX홀딩스': '383800',
#  '골프존': '215000',
#  '아이티엠반도체': '084850',
#  'LG생활건강우': '051905',
#  '현대에너지솔루션': '322000',
#  '넥센타이어': '002350',
#  '유니드': '014830',
#  '양지사': '030960',
#  'KCC글라스': '344820',
#  '우리종금': '010050',
#  '현대그린푸드': '005440',
#  '코스맥스': '192820',
#  '디어유': '376300',
#  '효성중공업': '298040',
#  '세아베스틸지주': '001430',
#  '휴마시스': '205470',
#  '한세실업': '105630',
#  '안랩': '053800',
#  '드림텍': '192650',
#  '쿠쿠홈시스': '284740',
#  'SNT모티브': '064960',
#  '케이카': '381970',
#  '서울반도체': '046890',
#  '한섬': '020000',
#  'DN오토모티브': '007340',
#  '파미셀': '005690',
#  '박셀바이오': '323990',
#  '에스앤에스텍': '101490',
#  '동아쏘시오홀딩스': '000640',
#  '파마리서치': '214450',
#  'RFHIC': '218410',
#  '진원생명과학': '011000',
#  '세방전지': '004490',
#  '주성엔지니어링': '036930',
#  '엔케이맥스': '182400',
#  '엘앤씨바이오': '290650',
#  '코리아센터': '290510',
#  '다원시스': '068240',
#  '화승엔터프라이즈': '241590',
#  '한국단자': '025540',
#  'SK디스커버리': '006120',
#  '위메이드맥스': '101730',
#  '오스코텍': '039200',
#  'SPC삼립': '005610',
#  '제넥신': '095700',
#  '서진시스템': '178320',
#  '티와이홀딩스': '363280',
#  'ISC': '095340',
#  '세아제강지주': '003030',
#  '지누스': '013890',
#  '인텔리안테크': '189300',
#  '이녹스첨단소재': '272290',
#  '유진테크': '084370',
#  '부광약품': '003000',
#  '삼양홀딩스': '000070',
#  'SBS': '034120',
#  '쏘카': '403550',
#  '쿠쿠홀딩스': '192400',
#  '한화투자증권': '003530',
#  '웹젠': '069080',
#  '한국정보통신': '025770',
#  '제주항공': '089590',
#  '현대홈쇼핑': '057050',
#  '솔브레인홀딩스': '036830',
#  '하나마이크론': '067310',
#  '코오롱글로벌': '003070',
#  '제이시스메디칼': '287410',
#  '넥스틴': '348210',
#  'NHN한국사이버결제': '060250',
#  '헬릭스미스': '084990',
#  '이오플로우': '294090',
#  '에이프로젠': '007460',
#  '아난티': '025980',
#  '피에스케이': '319660',
#  '삼성SDI우': '006405',
#  '인탑스': '049070',
#  '동원F&B': '049770',
#  '데브시스터즈': '194480',
#  '유안타증권': '003470',
#  '메드팩토': '235980',
#  '영진약품': '003520',
#  '셀리버리': '268600',
#  '한국카본': '017960',
#  '새빗켐': '107600',
#  '파트론': '091700',
#  '미래에셋증권2우B': '00680K',
#  '젬백스': '082270',
#  '엠씨넥스': '097520',
#  '신영증권': '001720',
#  '경동나비엔': '009450',
#  '프레스티지바이오파마': '950210',
#  '신한알파리츠': '293940',
#  '동아에스티': '170900',
#  '아모레퍼시픽우': '090435',
#  '삼성화재우': '000815',
#  '엑세스바이오': '950130',
#  '코미코': '183300',
#  '성우하이텍': '015750',
#  '하이드로리튬': '101670',
#  'HSD엔진': '082740',
#  '미래에셋생명': '085620',
#  '두산테스나': '131970',
#  '코미팜': '041960',
#  'SK디앤디': '210980',
#  'NICE': '034310',
#  '레인보우로보틱스': '277810',
#  '콘텐트리중앙': '036420',
#  '바텍': '043150',
#  '루트로닉': '085370',
#  '코웰패션': '033290',
#  '롯데손해보험': '000400',
#  'SGC에너지': '005090',
#  '하나기술': '299030',
#  '네패스': '033640',
#  '애경케미칼': '161000',
#  '티에스이': '131290',
#  '이엠텍': '091120',
#  '에코마케팅': '230360',
#  '에치에프알': '230240',
#  '자화전자': '033240',
#  '상아프론테크': '089980',
#  'LF': '093050',
#  '자이언트스텝': '289220',
#  '고려제강': '002240',
#  '디와이피엔에프': '104460',
#  'JW중외제약': '001060',
#  '태광': '023160',
#  '송원산업': '004430',
#  '남해화학': '025860',
#  '한화손해보험': '000370',
#  '툴젠': '199800',
#  '아이센스': '099190',
#  '효성화학': '298000',
#  '한국비엔씨': '256840',
#  '동일산업': '004890',
#  '인선이엔티': '060150',
#  '서부T&D': '006730',
#  'KB스타리츠': '432320',
#  '대보마그네틱': '290670',
#  '대명에너지': '389260',
#  '한미글로벌': '053690',
#  '풀무원': '017810',
#  'DI동일': '001530',
#  '유바이오로직스': '206650',
#  '코람코에너지리츠': '357120',
#  '세아제강': '306200',
#  '넵튠': '217270',
#  '다날': '064260',
#  '더네이쳐홀딩스': '298540',
#  '신성이엔지': '011930',
#  '성광벤드': '014620',
#  '유나이티드제약': '033270',
#  '애경산업': '018250',
#  '삼표시멘트': '038500',
#  '매일유업': '267980',
#  '아미코젠': '092040',
#  '바이오플러스': '099430',
#  'KG ETS': '151860',
#  '국도화학': '007690',
#  '세방': '004360',
#  '서흥': '008490',
#  '세아홀딩스': '058650',
#  '우리기술투자': '041190',
#  '코오롱플라스틱': '138490',
#  '빙그레': '005180',
#  '모트렉스': '118990',
#  '노터스': '278650',
#  'LG헬로비전': '037560',
#  '에이스침대': '003800',
#  '신영증권우': '001725',
#  '삼양사': '145990',
#  '코엔텍': '029960',
#  '이수페타시스': '007660',
#  '삼화콘덴서': '001820',
#  '한국자산신탁': '123890',
#  '휴온스': '243070',
#  '신흥에스이씨': '243840',
#  '스카이라이프': '053210',
#  '현대무벡스': '319400',
#  'SIMPAC': '009160',
#  '이연제약': '102460',
#  '네오이뮨텍': '950220',
#  '원익머트리얼즈': '104830',
#  '대원제약': '003220',
#  '에스피지': '058610',
#  '일동홀딩스': '000230',
#  '국전약품': '307750',
#  '잇츠한불': '226320',
#  '엠아이텍': '179290',
#  '한일현대시멘트': '006390',
#  '코리아써키트': '007810',
#  '메지온': '140410',
#  '롯데정보통신': '286940',
#  'HLB테라퓨틱스': '115450',
#  'KG이니시스': '035600',
#  '바이넥스': '053030',
#  '엘비세미콘': '061970',
#  '코오롱생명과학': '102940',
#  '아세아시멘트': '183190',
#  'CJ프레시웨이': '051500',
#  '흥아해운': '003280',
#  'KEC': '092220',
#  '맵스리얼티1': '094800',
#  '이엔플러스': '074610',
#  '테스': '095610',
#  '상상인': '038540',
#  '교보증권': '030610',
#  '휴림로봇': '090710',
#  '한국토지신탁': '034830',
#  'HLB제약': '047920',
#  '일양약품': '007570',
#  '탑머티리얼': '360070',
#  'HDC': '012630',
#  '삼진제약': '005500',
#  '도화엔지니어링': '002150',
#  '월덱스': '101160',
#  '이엔에프테크놀로지': '102710',
#  '한글과컴퓨터': '030520',
#  '신성통상': '005390',
#  '삼아알미늄': '006110',
#  'BGF': '027410',
#  'TYM': '002900',
#  '동성화인텍': '033500',
#  '아이마켓코리아': '122900',
#  'KG케미칼': '001390',
#  '대신증권우': '003545',
#  '케이씨텍': '281820',
#  '인트론바이오': '048530',
#  '인터로조': '119610',
#  'STX엔진': '077970',
#  '디오': '039840',
#  '압타바이오': '293780',
#  'SK렌터카': '068400',
#  '유티아이': '179900',
#  'HL홀딩스': '060980',
#  '이리츠코크렙': '088260',
#  '롯데하이마트': '071840',
#  '에프에스티': '036810',
#  '세진중공업': '075580',
#  '국일제지': '078130',
#  '사람인에이치알': '143240',
#  '락앤락': '115390',
#  '스마트솔루션즈': '136510',
#  '신대양제지': '016590',
#  '신도리코': '029530',
#  'DL건설': '001880',
#  '미코': '059090',
#  '윤성에프앤씨': '372170',
#  'SK증권': '001510',
#  'KH바텍': '060720',
#  '싸이토젠': '217330',
#  '한화3우B': '00088K',
#  '동원개발': '013120',
#  '한일홀딩스': '003300',
#  'LX하우시스': '108670',
#  '한솔제지': '213500',
#  '쏠리드': '050890',
#  '수산인더스트리': '126720',
#  '레이크머티리얼즈': '281740',
#  '아주IB투자': '027360',
#  '광동제약': '009290',
#  '환인제약': '016580',
#  '조광피혁': '004700',
#  '조이시티': '067000',
#  '아세아제지': '002310',
#  '덕산테코피아': '317330',
#  '에이피티씨': '089970',
#  '퍼시스': '016800',
#  '대한제강': '084010',
#  'HJ중공업': '097230',
#  '한전산업': '130660',
#  '루닛': '328130',
#  '한국쉘석유': '002960',
#  '이랜텍': '054210',
#  '한진': '002320',
#  'HLB글로벌': '003580',
#  '화신': '010690',
#  '한국기업평가': '034950',
#  '보로노이': '310210',
#  '동국S&C': '100130',
#  'SM C&C': '048550',
#  'CMG제약': '058820',
#  '지역난방공사': '071320',
#  '방림': '003610',
#  '서울옥션': '063170',
#  '디아크': '078590',
#  '뷰웍스': '100120',
#  '원준': '382840',
#  '유틸렉스': '263050',
#  '현대차증권': '001500',
#  '오킨스전자': '080580',
#  '모두투어': '080160',
#  '네패스아크': '330860',
#  '제우스': '079370',
#  '조선내화': '000480',
#  '뉴지랩파마': '214870',
#  '코오롱': '002020',
#  '포스코엠텍': '009520',
#  '원익피앤이': '131390',
#  'YTN': '040300',
#  '대성에너지': '117580',
#  '삼부토건': '001470',
#  '유니테스트': '086390',
#  '쿠콘': '294570',
#  '교촌에프앤비': '339770',
#  'CJ4우(전환)': '00104K',
#  '웅진씽크빅': '095720',
#  '이베스트투자증권': '078020',
#  '티케이케미칼': '104480',
#  'E1': '017940',
#  '하림': '136480',
#  '엘브이엠씨홀딩스': '900140',
#  '경방': '000050',
#  '로보티즈': '108490',
#  '아바텍': '149950',
#  '컴투스홀딩스': '063080',
#  '농심홀딩스': '072710',
#  '이엔드디': '101360',
#  '테이팩스': '055490',
#  '나스미디어': '089600',
#  '현대퓨처넷': '126560',
#  '하이록코리아': '013030',
#  '티앤알바이오팹': '246710',
#  'KX': '122450',
#  '제이앤티씨': '204270',
#  '남양유업': '003920',
#  'SNT중공업': '003570',
#  '서희건설': '035890',
#  '제일약품': '271980',
#  'AP시스템': '265520',
#  '무림P&P': '009580',
#  '톱텍': '108230',
#  '큐렉소': '060280',
#  '티웨이항공': '091810',
#  '올릭스': '226950',
#  '에스에이엠티': '031330',
#  '비츠로셀': '082920',
#  '진성티이씨': '036890',
#  '한국콜마홀딩스': '024720',
#  '풍산홀딩스': '005810',
#  '아나패스': '123860',
#  '와이아이케이': '232140',
#  '유진기업': '023410',
#  '시너지이노베이션': '048870',
#  '모다이노칩': '080420',
#  '금호석유우': '011785',
#  '경동인베스트': '012320',
#  '한국파마': '032300',
#  '남선알미늄': '008350',
#  'AJ네트웍스': '095570',
#  '한국금융지주우': '071055',
#  '케이티알파': '036030',
#  '유비쿼스홀딩스': '078070',
#  '신성델타테크': '065350',
#  '풍원정밀': '371950',
#  '티앤엘': '340570',
#  '다올인베스트먼트': '298870',
#  '네오위즈홀딩스': '042420',
#  '덱스터': '206560',
#  '레이': '228670',
#  '파세코': '037070',
#  '성신양회': '004980',
#  '해성산업': '034810',
#  '원텍': '336570',
#  '종근당홀딩스': '001630',
#  '코나아이': '052400',
#  '삼목에스폼': '018310',
#  '하나제약': '293480',
#  'YG PLUS': '037270',
#  '한국철강': '104700',
#  '모토닉': '009680',
#  '삼성출판사': '068290',
#  '하이비젼시스템': '126700',
#  '티움바이오': '321550',
#  '대한방직': '001070',
#  '조일알미늄': '018470',
#  '덕산하이메탈': '077360',
#  '앱클론': '174900',
#  '원익홀딩스': '030530',
#  '유비케어': '032620',
#  '에어부산': '298690',
#  '한양이엔지': '045100',
#  '키다리스튜디오': '020120',
#  '범한퓨얼셀': '382900',
#  '동화약품': '000020',
#  '케이아이엔엑스': '093320',
#  '큐브엔터': '182360',
#  'APS홀딩스': '054620',
#  '프로텍': '053610',
#  'NPC': '004250',
#  '대상홀딩스': '084690',
#  '인터플렉스': '051370',
#  'TCC스틸': '002710',
#  '엠케이전자': '033160',
#  '나이스정보통신': '036800',
#  '대동': '000490',
#  '일성신약': '003120',
#  'WI': '073570',
#  '삼익THK': '004380',
#  '삼양패키징': '272550',
#  '클리오': '237880',
#  '미원홀딩스': '107590',
#  '상신이디피': '091580',
#  '강원에너지': '114190',
#  '아바코': '083930',
#  '광주신세계': '037710',
#  '아세아': '002030',
#  '제주은행': '006220',
#  '바디텍메드': '206640',
#  '크리스탈지노믹스': '083790',
#  '스틱인베스트먼트': '026890',
#  '테크윙': '089030',
#  '한신기계': '011700',
#  '아주스틸': '139990',
#  '에이스테크': '088800',
#  '코윈테크': '282880',
#  '동양': '001520',
#  '지놈앤컴퍼니': '314130',
#  '켐트로닉스': '089010',
#  '카페24': '042000',
#  '위메이드플레이': '123420',
#  'SK시그넷': '260870',
#  '인바디': '041830',
#  '금호건설': '002990',
#  '쎄트렉아이': '099320',
#  '유진투자증권': '001200',
#  '그린케미칼': '083420',
#  '메디포스트': '078160',
#  '자이에스앤디': '317400',
#  '동국산업': '005160',
#  '하이트진로홀딩스': '000140',
#  '일진다이아': '081000',
#  '크리스에프앤씨': '110790',
#  '유니슨': '018000',
#  '새로닉스': '042600',
#  '태림포장': '011280',
#  '휴온스글로벌': '084110',
#  '비덴트': '121800',
#  '씨에스베어링': '297090',
#  'SBW생명과학': '151910',
#  '대한제당': '001790',
#  '이월드': '084680',
#  '초록뱀미디어': '047820',
#  '한국알콜': '017890',
#  '아이디스': '143160',
#  '유니퀘스트': '077500',
#  '일신방직': '003200',
#  '골프존뉴딘홀딩스': '121440',
#  'KG모빌리언스': '046440',
#  '경동제약': '011040',
#  '서연이화': '200880',
#  '파인엠텍': '441270',
#  '켐트로스': '220260',
#  '랩지노믹스': '084650',
#  '비나텍': '126340',
#  '아모그린텍': '125210',
#  'LS전선아시아': '229640',
#  'SNT홀딩스': '036530',
#  '삼영무역': '002810',
#  '대아티아이': '045390',
#  '와이엠티': '251370',
#  '현대코퍼레이션': '011760',
#  '한국캐피탈': '023760',
#  '가온칩스': '399720',
#  '마크로젠': '038290',
#  '다나와': '119860',
#  'S-Oil우': '010955',
#  'GS글로벌': '001250',
#  '유일로보틱스': '388720',
#  '알루코': '001780',
#  'KPX케미칼': '025000',
#  'HB솔루션': '297890',
#  '팜스토리': '027710',
#  '알서포트': '131370',
#  'BYC': '001460',
#  '우리기술': '032820',
#  '한독': '002390',
#  '케이씨': '029460',
#  '헥토파이낸셜': '234340',
#  '그래디언트': '035080',
#  '보광산업': '225530',
#  '동성케미컬': '102260',
#  '맥스트': '377030',
#  '크레버스': '096240',
#  '씨앤씨인터내셔널': '352480',
#  '에스티아이': '039440',
#  '프레스티지바이오로직스': '334970',
#  '휴스틸': '005010',
#  '포인트모바일': '318020',
#  '사조대림': '003960',
#  '에이프로': '262260',
#  '대한제분': '001130',
#  'KPX홀딩스': '092230',
#  '노바텍': '285490',
#  '화승인더': '006060',
#  '신세계 I&C': '035510',
#  '한일사료': '005860',
#  '휴메딕스': '200670',
#  'CJ제일제당 우': '097955',
#  '엔피': '291230',
#  '백산': '035150',
#  '지니뮤직': '043610',
#  '영풍제지': '006740',
#  '미래에셋벤처투자': '100790',
#  '대원강업': '000430',
#  '서울바이오시스': '092190',
#  '인트로메딕': '150840',
#  '쇼박스': '086980',
#  '대교': '019680',
#  '와이엠텍': '273640',
#  '갤럭시아머니트리': '094480',
#  '아모텍': '052710',
#  '대덕': '008060',
#  '한솔아이원스': '114810',
#  '디엑스앤브이엑스': '180400',
#  '보성파워텍': '006910',
#  '넥센': '005720',
#  '브릿지바이오테라퓨틱스': '288330',
#  'KISCO홀딩스': '001940',
#  '비에이치아이': '083650',
#  '일진홀딩스': '015860',
#  '에이디테크놀로지': '200710',
#  '이원컴포텍': '088290',
#  '나이벡': '138610',
#  '동일금속': '109860',
#  '일진파워': '094820',
#  'KSS해운': '044450',
#  '태웅로직스': '124560',
#  '유니셈': '036200',
#  '엠투엔': '033310',
#  '슈피겐코리아': '192440',
#  '사조산업': '007160',
#  'GST': '083450',
#  '웹케시': '053580',
#  '와이지-원': '019210',
#  '디앤디플랫폼리츠': '377190',
#  '제테마': '216080',
#  '아이에이': '038880',
#  '티엘비': '356860',
#  '신한서부티엔디리츠': '404990',
#  '두산우': '000155',
#  '비씨엔씨': '146320',
#  '디지털대성': '068930',
#  '한국정보인증': '053300',
#  '퓨쳐켐': '220100',
#  '이크레더블': '092130',
#  '엘오티베큠': '083310',
#  '리드코프': '012700',
#  '동아지질': '028100',
#  '멀티캠퍼스': '067280',
#  '이수앱지스': '086890',
#  '금호에이치티': '214330',
#  '삼성전기우': '009155',
#  '도이치모터스': '067990',
#  '엠에스오토텍': '123040',
#  '샘씨엔에스': '252990',
#  'JW홀딩스': '096760',
#  '경인양행': '012610',
#  '영풍정밀': '036560',
#  'LS네트웍스': '000680',
#  '시노펙스': '025320',
#  '피에이치씨': '057880',
#  '코닉오토메이션': '391710',
#  '한농화성': '011500',
#  '백광산업': '001340',
#  '한세예스24홀딩스': '016450',
#  '현대리바트': '079430',
#  '삼성제약': '001360',
#  '이지홀딩스': '035810',
#  '제이브이엠': '054950',
#  '제이에스코퍼레이션': '194370',
#  '좋은사람들': '033340',
#  '다올투자증권': '030210',
#  '한양디지텍': '078350',
#  '피코그램': '376180',
#  '펌텍코리아': '251970',
#  '이녹스': '088390',
#  '에이스토리': '241840',
#  '선진': '136490',
#  '에이프로젠제약': '003060',
#  '와이솔': '122990',
#  '이노와이어리스': '073490',
#  '에스엠벡셀': '010580',
#  '삼영전자': '005680',
#  '유일에너테크': '340930',
#  '지노믹트리': '228760',
#  'HDC랩스': '039570',
#  '태경산업': '015890',
#  '동운아나텍': '094170',
#  'SBI인베스트먼트': '019550',
#  '공구우먼': '366030',
#  '파워로직스': '047310',
#  '세아특수강': '019440',
#  '에이프릴바이오': '397030',
#  '현대바이오랜드': '052260',
#  '진흥기업': '002780',
#  '미투젠': '950190',
#  '고바이오랩': '348150',
#  '대화제약': '067080',
#  '텔레칩스': '054450',
#  '우진': '105840',
#  '대성산업': '128820',
#  '노바렉스': '194700',
#  'AK홀딩스': '006840',
#  'JW생명과학': '234080',
#  '위닉스': '044340',
#  '현대차3우B': '005389',
#  '대창단조': '015230',
#  '부국증권': '001270',
#  '인크로스': '216050',
#  '나무가': '190510',
#  '플리토': '300080',
#  '에브리봇': '270660',
#  '인텍플러스': '064290',
#  '경농': '002100',
#  '어보브반도체': '102120',
#  '청담글로벌': '362320',
#  '브이티지엠피': '018290',
#  '흥국화재': '000540',
#  '신세계푸드': '031440',
#  '오픈엣지테크놀로지': '394280',
#  '예스코홀딩스': '015360',
#  '오이솔루션': '138080',
#  'LG우': '003555',
#  '로보스타': '090360',
#  '셀루메드': '049180',
#  '태웅': '044490',
#  '슈프리마': '236200',
#  '미래컴퍼니': '049950',
#  '뉴로메카': '348340',
#  '제이씨케미칼': '137950',
#  'DB금융투자': '016610',
#  '동남합성': '023450',
#  '켄코아에어로스페이스': '274090',
#  '일진전기': '103590',
#  '세종텔레콤': '036630',
#  '푸른저축은행': '007330',
#  '아이에스이커머스': '069920',
#  '코람코더원리츠': '417310',
#  '엘비루셈': '376190',
#  '포스코스틸리온': '058430',
#  '유수홀딩스': '000700',
#  '신라교역': '004970',
#  'GRT': '900290',
#  '윈스': '136540',
#  '아모레G3우(전환)': '00279K',
#  '해태제과식품': '101530',
#  '큐라클': '365270',
#  '현대에버다임': '041440',
#  '현대비앤지스틸': '004560',
#  '에스퓨얼셀': '288620',
#  '샤페론': '378800',
#  '수젠텍': '253840',
#  '엔지켐생명과학': '183490',
#  '대한광통신': '010170',
#  '휴비스': '079980',
#  '아미노로직스': '074430',
#  '인스코비': '006490',
#  'NEW': '160550',
#  'EDGC': '245620',
#  'NH투자증권우': '005945',
#  '삼성물산우B': '02826K',
#  '연우': '115960',
#  '에스와이': '109610',
#  '세원이앤씨': '091090',
#  '동아화성': '041930',
#  '디앤씨미디어': '263720',
#  '레이언스': '228850',
#  '올리패스': '244460',
#  '대한약품': '023910',
#  '진양홀딩스': '100250',
#  '모비데이즈': '363260',
#  '한솔테크닉스': '004710',
#  '디엔에프': '092070',
#  '비즈니스온': '138580',
#  '태영건설': '009410',
#  '라파스': '214260',
#  'CJ 바이오사이언스': '311690',
#  '동성제약': '002210',
#  '동구바이오제약': '006620',
#  '플래스크': '041590',
#  '필옵틱스': '161580',
#  ...}

# %%
from datetime import datetime

today = datetime.today()

year = today.year
month = today.month
day = today.day

# %%
s_day = str(year-1)+'-'+str(month)+'-'+str(day) # 시작날짜
l_day = str(year)  +'-'+str(month)+'-'+str(day) # 종료날짜

print('시작 날짜 :', s_day)
print('종료 날짜 :', l_day)
# Out:
# 시작 날짜 : 2021-11-15
# 종료 날짜 : 2022-11-15

# %%
# 해당 종목에 맞는 종가 구하기

df_stock = fdr.DataReader(name_code_dict['삼성전자'],s_day,l_day)
df_stock['삼성전자'] = df_stock['Close']

df_stock
# Out:
#              Open   High    Low  Close    Volume    Change   삼성전자
# Date
# 2021-11-15  71700  71900  70900  71400  12420710  0.011331  71400
# 2021-11-16  71500  72000  71300  71300  10919239 -0.001401  71300
# 2021-11-17  71300  71600  70600  70700  11027606 -0.008415  70700
# 2021-11-18  70700  71000  70200  70200  10144957 -0.007072  70200
# 2021-11-19  70400  71400  70100  71200  11954728  0.014245  71200
# ...           ...    ...    ...    ...       ...       ...    ...
# 2022-11-09  62000  62200  61300  62000  14045592  0.003236  62000
# 2022-11-10  61400  61500  60400  60400  21087633 -0.025806  60400
# 2022-11-11  63100  63200  62300  62900  20037163  0.041391  62900
# 2022-11-14  62900  62900  61700  61900  15973416 -0.015898  61900
# 2022-11-15  62200  62500  61600  62400  12207263  0.008078  62400
#
# [248 rows x 7 columns]

# %%
hyunbo_list = ['셀트리온','HLB','현대차','SK케미칼','한국전력','카카오']

# %%
import pandas as pd

i=0
for s in hyunbo_list :
    stock_code = name_code_dict[s]
    temp_df = fdr.DataReader(stock_code,s_day,l_day)
    temp_df[s] = temp_df['Close']
    temp_df = temp_df[s]
    
    if i==0:
        df_stock = temp_df
        i+=1
    else:
        df_stock = pd.concat([df_stock, temp_df], axis=1)

# %%
df_stock
# Out:
#               셀트리온    HLB     현대차   SK케미칼   한국전력     카카오
# Date
# 2021-11-15  228685  38780  209000  152500  22850  129000
# 2021-11-16  224759  40298  206500  150500  22800  127500
# 2021-11-17  214944  39074  207000  147500  22400  125000
# 2021-11-18  211019  38143  205000  144000  22300  124500
# 2021-11-19  218870  40886  209500  145500  22300  127000
# ...            ...    ...     ...     ...    ...     ...
# 2022-11-09  187500  37100  169500   90600  18600   52100
# 2022-11-10  187000  35900  169500   90000  18150   50800
# 2022-11-11  192000  38700  172000   92200  19000   58700
# 2022-11-14  185000  39050  176000  101000  19400   58500
# 2022-11-15  188000  38800  174500  107500  19350   58700
#
# [248 rows x 6 columns]

# %%
df_stock=df_stock.reset_index(drop=False).sort_values(by='Date', ascending=False)

# %%
df_stock=df_stock.reset_index(drop=True)
df_stock
# Out:
#           Date    셀트리온    HLB     현대차   SK케미칼   한국전력     카카오
# 0   2022-11-15  188000  38800  174500  107500  19350   58700
# 1   2022-11-14  185000  39050  176000  101000  19400   58500
# 2   2022-11-11  192000  38700  172000   92200  19000   58700
# 3   2022-11-10  187000  35900  169500   90000  18150   50800
# 4   2022-11-09  187500  37100  169500   90600  18600   52100
# ..         ...     ...    ...     ...     ...    ...     ...
# 243 2021-11-19  218870  40886  209500  145500  22300  127000
# 244 2021-11-18  211019  38143  205000  144000  22300  124500
# 245 2021-11-17  214944  39074  207000  147500  22400  125000
# 246 2021-11-16  224759  40298  206500  150500  22800  127500
# 247 2021-11-15  228685  38780  209000  152500  22850  129000
#
# [248 rows x 7 columns]

# %%
# 상관계수 구하기

df_stock.corr()
# Out:
#            셀트리온       HLB       현대차     SK케미칼      한국전력       카카오
# 셀트리온   1.000000  0.260619  0.554784  0.216118 -0.063219  0.384231
# HLB    0.260619  1.000000  0.192271 -0.388301 -0.295592 -0.388766
# 현대차    0.554784  0.192271  1.000000  0.648965  0.196027  0.582522
# SK케미칼  0.216118 -0.388301  0.648965  1.000000  0.521754  0.910232
# 한국전력  -0.063219 -0.295592  0.196027  0.521754  1.000000  0.626612
# 카카오    0.384231 -0.388766  0.582522  0.910232  0.626612  1.000000

# %%
# 공분산 구하기

df_stock.cov()
# Out:
#                셀트리온           HLB           현대차         SK케미칼          한국전력  \
# 셀트리온   3.548403e+08  2.892533e+07  1.493131e+08  8.447436e+07 -2.049748e+06
# HLB    2.892533e+07  3.471445e+07  1.618551e+07 -4.747238e+07 -2.997667e+06
# 현대차    1.493131e+08  1.618551e+07  2.041338e+08  1.923964e+08  4.820676e+06
# SK케미칼  8.447436e+07 -4.747238e+07  1.923964e+08  4.305622e+08  1.863455e+07
# 한국전력  -2.049748e+06 -2.997667e+06  4.820676e+06  1.863455e+07  2.962580e+06
# 카카오    1.539817e+08 -4.873088e+07  1.770641e+08  4.018190e+08  2.294533e+07
#
#                 카카오
# 셀트리온   1.539817e+08
# HLB   -4.873088e+07
# 현대차    1.770641e+08
# SK케미칼  4.018190e+08
# 한국전력   2.294533e+07
# 카카오    4.526065e+08
